# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([[-1, -1], [1, -1], [-1, 1], [1, 1]])
y = np.array([-1, -1, -1, 1])

# %%
weights = np.random.rand(2)
bias = np.random.rand()
learning_rate = 0.1
epochs = 100

# %%
for epoch in range(epochs):
    for i in range(len(X)):
        output = np.dot(X[i], weights) + bias
        error = y[i] - output
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

# %%
print('Final Weights:', weights)
print('Final Bias:', bias)
# Out:
# Final Weights: [0.55882353 0.52941176]
# Final Bias: -0.5000000000000001

# %%
if weights[1] != 0:
    x_vals = np.linspace(-2, 2, 100)
    y_vals = -(weights[0] * x_vals + bias) / weights[1]
    plt.figure(figsize=(6, 6))
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(True, linestyle='--', linewidth=0.5)
    plt.plot(x_vals, y_vals, 'r-', label='Decision Boundary')

for i in range(len(X)):
    plt.scatter(X[i][0], X[i][1], c='blue' if y[i] == 1 else 'red', marker='o', edgecolors='black', s=100, label=f'Class{y[i]}')
plt.xlabel('Input 1')
plt.ylabel('Input 2')
plt.title("Delta Rule - Decision Boundary")
plt.legend(loc = "best")
plt.show()
