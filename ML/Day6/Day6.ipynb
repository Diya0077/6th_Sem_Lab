# %%
pip install docx2txt
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 859.0 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 962.5 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 938.9 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 986.5 kB/s  0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# ...

# %%
pip install docx2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement docx2 (from versions: none)
# ERROR: No matching distribution found for docx2
